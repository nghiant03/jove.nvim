# %% [markdown]
# # Outputs fixture
#
# Exercises stream, execute_result, error, and an output-less code cell.

# %%
x = 41
x + 1
# Out:
# 42

# %%
y = 7
y * 7
# Out:
# 49

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 1 / 0
# ZeroDivisionError: division by zero

# %%
ready = True
